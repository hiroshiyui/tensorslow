# %%
import torch
if torch.cuda.is_available(): print("CUDA is available")
# Out:
# CUDA is available

# %%
import tensorflow as tf
tf.test.is_gpu_available()
# Out:
# I0000 00:00:1763388257.910893    7041 gpu_device.cc:2020] Created device /device:GPU:0 with 9906 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# True

# %%
tf.sysconfig.get_build_info()
# Out:
# OrderedDict([('cpu_compiler', 'clang 18'),
#              ('cuda_compute_capabilities',
#               ['sm_60', 'sm_70', 'sm_80', 'sm_89', 'compute_90']),
#              ('cuda_version', '12.5.1'),
#              ('cudnn_version', '9'),
#              ('is_cuda_build', True),
#              ('is_rocm_build', False),
#              ('is_tensorrt_build', False)])

# %%
tf.config.list_physical_devices('CPU')
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
